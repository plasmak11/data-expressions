# %% [markdown]
# # Bar Chart
#
# Bar chart is the bread and butter of data visualization. You can basically meet 90% of data analytics needs with bar chart.

# %% [markdown]
# ## Explore the data
#
# Polars is my favorite dataframe library. There is an interesting open-source effort in biomedical space called OpenTargets.
#
# Downloaded the (tab-separated value) from OpenTargets:

# %% [markdown]
# ![Alt text](iga_neph.png)

# %%
import polars as pl

df = pl.read_csv("data/EFO_0004194-known-drugs.tsv", separator="\t")
df.head(10).to_pandas()
# Out:
#      diseaseId             diseaseName         drugId  \
# 0  EFO_0004194  IGA glomerulonephritis   CHEMBL429910
# 1  EFO_0004194  IGA glomerulonephritis     CHEMBL1168
# 2  EFO_0004194  IGA glomerulonephritis     CHEMBL1535
# 3  EFO_0004194  IGA glomerulonephritis     CHEMBL1639
# 4  EFO_0004194  IGA glomerulonephritis  CHEMBL4594217
# 5  EFO_0004194  IGA glomerulonephritis     CHEMBL1535
# 6  EFO_0004194  IGA glomerulonephritis      CHEMBL578
# 7  EFO_0004194  IGA glomerulonephritis     CHEMBL1456
# 8  EFO_0004194  IGA glomerulonephritis     CHEMBL1069
# 9  EFO_0004194  IGA glomerulonephritis     CHEMBL1690
#
#                      drugName            type  \
# 0               DAPAGLIFLOZIN  Small molecule
# 1                    RAMIPRIL  Small molecule
# 2          HYDROXYCHLOROQUINE  Small molecule
# 3                   ALISKIREN  Small molecule
# 4               CANAGLIFLOZIN  Small molecule
# 5          HYDROXYCHLOROQUINE  Small molecule
# 6                   ENALAPRIL  Small molecule
# 7       MYCOPHENOLATE MOFETIL  Small molecule
# 8                   VALSARTAN  Small molecule
# 9  HYDROXYCHLOROQUINE SULFATE  Small molecule
#
#                                    mechanismOfAction  actionType  symbol  \
# 0           Sodium/glucose cotransporter 2 inhibitor   Inhibitor  SLC5A2
# 1            Angiotensin-converting enzyme inhibitor   Inhibitor     ACE
# 2                    Toll-like receptor 7 antagonist  Antagonist    TLR7
# 3                                    Renin inhibitor   Inhibitor     REN
# 4           Sodium/glucose cotransporter 2 inhibitor   Inhibitor  SLC5A2
# 5                    Toll-like receptor 9 antagonist  Antagonist    TLR9
# 6            Angiotensin-converting enzyme inhibitor   Inhibitor     ACE
# 7  Inosine-5'-monophosphate dehydrogenase (IMPDH)...   Inhibitor  IMPDH1
# 8          Type-1 angiotensin II receptor antagonist  Antagonist   AGTR1
# 9                    Toll-like receptor 7 antagonist  Antagonist    TLR7
#
#                                     name  phase              status  \
# 0       solute carrier family 5 member 2      4  Not yet recruiting
# 1        angiotensin I converting enzyme      4  Not yet recruiting
# 2                   toll like receptor 7      4           Completed
# 3                                  renin      4           Completed
# 4       solute carrier family 5 member 2      4  Not yet recruiting
# 5                   toll like receptor 9      4           Completed
# 6        angiotensin I converting enzyme      4           Completed
# 7  inosine monophosphate dehydrogenase 1      4      Unknown status
# 8         angiotensin II receptor type 1      4      Unknown status
# 9                   toll like receptor 7      4           Completed
#
#                                             source
# 0  https://clinicaltrials.gov/ct2/show/NCT04662723
# 1  https://clinicaltrials.gov/ct2/show/NCT04662723
# 2  https://clinicaltrials.gov/ct2/show/NCT02351752
# 3  https://clinicaltrials.gov/ct2/show/NCT00922311
# 4  https://clinicaltrials.gov/ct2/show/NCT04662723
# 5  https://clinicaltrials.gov/ct2/show/NCT02351752
# 6  https://clinicaltrials.gov/ct2/show/NCT00367562
# 7  https://clinicaltrials.gov/ct2/show/NCT02981212
# 8  https://clinicaltrials.gov/ct2/show/NCT02765594
# 9  https://clinicaltrials.gov/ct2/show/NCT02351752

# %% [markdown]
# # Bar-chart as exploratory data analysis

# %%
df
# Out:
# shape: (86, 12)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬───────┬───────────┬───────────┐
# │ diseaseId  ┆ diseaseNam ┆ drugId     ┆ drugName  ┆ … ┆ name      ┆ phase ┆ status    ┆ source    │
# │ ---        ┆ e          ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---   ┆ ---       ┆ ---       │
# │ str        ┆ ---        ┆ str        ┆ str       ┆   ┆ str       ┆ i64   ┆ str       ┆ str       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════╪═══════════╪═══════════╡
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL4299 ┆ DAPAGLIFL ┆ … ┆ solute    ┆ 4     ┆ Not yet   ┆ https://c │
# │ 4          ┆ ulonephrit ┆ 10         ┆ OZIN      ┆   ┆ carrier   ┆       ┆ recruitin ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ family 5  ┆       ┆ g         ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ member 2  ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1168 ┆ RAMIPRIL  ┆ … ┆ angiotens ┆ 4     ┆ Not yet   ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆ in I conv ┆       ┆ recruitin ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ erting    ┆       ┆ g         ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ enzyme    ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1535 ┆ HYDROXYCH ┆ … ┆ toll like ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆ LOROQUINE ┆   ┆ receptor  ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ 7         ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1639 ┆ ALISKIREN ┆ … ┆ renin     ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆           ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆           ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …     ┆ …         ┆ …         │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL578  ┆ ENALAPRIL ┆ … ┆ angiotens ┆ 2     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆ in I conv ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ erting    ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ enzyme    ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL3989 ┆ FOSTAMATI ┆ … ┆ spleen    ┆ 2     ┆ Withdrawn ┆ https://c │
# │ 4          ┆ ulonephrit ┆ 516        ┆ NIB       ┆   ┆ associate ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆ DISODIUM  ┆   ┆ d         ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ tyrosine  ┆       ┆           ┆ ct2/s…    │
# │            ┆            ┆            ┆           ┆   ┆ kinas…    ┆       ┆           ┆           │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL4297 ┆ CEMDISIRA ┆ … ┆ complemen ┆ 2     ┆ Active,   ┆ https://c │
# │ 4          ┆ ulonephrit ┆ 722        ┆ N         ┆   ┆ t C5      ┆       ┆ not recru ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆           ┆       ┆ iting     ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL4594 ┆ SIBEPRENL ┆ … ┆ TNF super ┆ 1     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆ 614        ┆ IMAB      ┆   ┆ family    ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ member 13 ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴───────┴───────────┴───────────┘

# %% [markdown]
# ### Data Summary
#
# The data contains:
# - row-by-row information for disease IgA glomerulonephritis (IgA nephropathy)

# %% [markdown]
# ###

# %% [markdown]
# ## Exploration Steps:
#
# ### Start small
#
# For starters, an easy way to explore complex datasets like this is to explore seemingly obvious ones.
#
# `status` column is relatively understandable, even if you don't come from biomedical background - 10 row preview shows

# %%
import altair as alt

alt.Chart(df).mark_bar().encode(
    x="distinct(drugId):Q",
    y="status:O",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ```{note}
#
# Titles like "Distinct of drugID" won't get you any points for good data visualization.
#
# ```

# %%
import altair as alt

alt.Chart(df).mark_bar().encode(
    x=alt.X("distinct(drugId):Q").title("Number of Unique Drugs"), 
    y=alt.Y("mechanismOfAction:O").title(None),
)
# Out:
# alt.Chart(...)
