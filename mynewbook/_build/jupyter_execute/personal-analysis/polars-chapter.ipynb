# %%
import owlready2

hpo = owlready2.get_ontology("http://purl.obolibrary.org/obo/hp.owl").load()
efo = owlready2.get_ontology("http://www.ebi.ac.uk/efo/efo.owl").load()
mondo = owlready2.get_ontology("http://purl.obolibrary.org/obo/mondo.owl").load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import owlready2
#       3 hpo = owlready2.get_ontology("http://purl.obolibrary.org/obo/hp.owl").load()
# ----> 4 efo = owlready2.get_ontology("http://www.ebi.ac.uk/efo/efo.owl").load()
#       5 mondo = owlready2.get_ontology("http://purl.obolibrary.org/obo/mondo.owl").load()
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/owlready2/namespace.py:964, in Ontology.load(self, only_local, fileobj, reload, reload_if_newer, url, **args)
#     962     raise OwlReadyOntologyParsingError("Cannot download '%s'!" % (url or f))
#     963 try:
# --> 964   new_base_iri = self.graph.parse(fileobj, default_base = self._orig_base_iri, **args)
#     965 except OwlReadyOntologyParsingError:
#     966   if f.endswith(".owl") or f.endswith(".rdf") or f.endswith(".xml") or url: raise
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/owlready2/driver.py:264, in BaseSubGraph.parse(self, f, format, delete_existing_triples, default_base)
#     262   else:
#     263     queue = _FakeQueue(*self.import_triples_from_queue(None, getattr(f, "name", ""), delete_existing_triples))
# --> 264     onto_base_iri = do_parse(800000)
#     266 except OwlReadyOntologyParsingError as e:
#     267   if len(self) == 0: self._add_obj_triple_raw_spo(self.onto.storid, rdf_type, owl_ontology)
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/owlready2/driver.py:218, in BaseSubGraph.parse.<locals>.do_parse(batch_size)
#     216 try:
#     217   if owlready2_optimized:
# --> 218     if   format == "rdfxml": owlready2_optimized.parse_rdfxml(f, queue, default_base, batch_size)
#     219     elif format == "owlxml": owlready2_optimized.parse_owlxml(f, queue, default_base, batch_size)
#     220   else:
#
# File owlready2_optimized.pyx:371, in owlready2_optimized.parse_rdfxml()
#
# File ~/.python/current/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/.python/current/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.python/current/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.python/current/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
search_term = "schizo"

# Crude searcher

def obo_searcher(search_term):
    hpo_results = hpo.search(label = f"*{search_term}*", _case_sensitive=False)
    efo_results = efo.search(label = f"*{search_term}*", _case_sensitive=False)
    mondo_results = mondo.search(label = f"*{search_term}*", _case_sensitive=False)


    hpo_data = [{
        "label": x.label,
        "iri": x.iri,
        "subclasses": list(x.subclasses()),
        "xrefs": x.hasDbXref,
        "source": "HPO"
    } for x in hpo_results if str(x.label)]


    efo_data = [{
        "label": x.label,
        "iri": x.iri,
        "subclasses": list(x.subclasses()),
        "xrefs": x.hasDbXref,
        "source": "EFO"
    } for x in efo_results if str(x.label)]

    mondo_data = [{
        "label": x.label,
        "iri": x.iri,
        "subclasses": list(x.subclasses()),
        "xrefs": x.hasDbXref,
        "source": "MONDO"
    } for x in mondo_results if str(x.label)]

    return (hpo_data + efo_data + mondo_data)

# %%
search_input = alt.param(
    value='',
    bind=alt.binding(
        input='search',
        placeholder="Car model",
        name='Search ',
    )
)
alt.Chart(data.cars.url).mark_point(size=60).encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    tooltip='Name:N',
    opacity=alt.condition(
        alt.expr.test(alt.expr.regexp(search_input, 'i'), alt.datum.Name),
        # f"test(regexp({search_input.name}, 'i'), datum.Name)",  # Equivalent js alternative
        alt.value(1),
        alt.value(0.05)
    )
).add_params(
    search_input
)

# %%
import pandas as pd

results = obo_searcher(search_term)

# %%
results
# Out:
# [{'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'HPO'},
#  {'label': ['Schizosaccharomyces pombe'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4896',
#   'subclasses': [obo.NCBITaxon_284812],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['schizotypal personality disorder',
#    'schizotypal personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001087',
#   'subclasses': [],
#   'xrefs': ['DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006',
#    'DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006'],
#   'source': 'HPO'},
#  {'label': ['schizoid personality disorder', 'schizoid personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001161',
#   'subclasses': [],
#   'xrefs': ['DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000',
#    'DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizosaccharomyces pombe 972h-'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_284812',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizosaccharomyces japonicus'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4897',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizophyllum commune'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_5334',
#   'subclasses': [],
#   'xrefs': ['SNOMEDCT:243445006'],
#   'source': 'HPO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'HPO'},
#  {'label': ['hepatic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002589',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000322'],
#   'source': 'HPO'},
#  {'label': ['erythrocytic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002591',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000306'],
#   'source': 'HPO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'HPO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0005411',
#   'subclasses': [efo.EFO_0009965],
#   'xrefs': ['DOID:5418',
#    'ICD10:F25',
#    'ICD9:295.7',
#    'MONDO:0005487',
#    'MedDRA:10039621',
#    'NCIT:C94378',
#    'NCIt:C94378',
#    'SNOMEDCT:68890003'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'HPO'},
#  {'label': ['Schizoaffective disorder-bipolar type'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0009965',
#   'subclasses': [],
#   'xrefs': ['PMID:31043756',
#    'https://en.wikipedia.org/wiki/Schizoaffective_disorder'],
#   'source': 'HPO'},
#  {'label': ['schizophreniform disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001265',
#   'subclasses': [],
#   'xrefs': ['DOID:11328',
#    'ICD10CM:F20.81',
#    'ICD9:295.4',
#    'NCIT:C94376',
#    'SCTID:88975006'],
#   'source': 'HPO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'HPO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'HPO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005487',
#   'subclasses': [],
#   'xrefs': ['DOID:5418', 'EFO:0005411', 'ICD9:295.7', 'NCIT:C94378'],
#   'source': 'HPO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'HPO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'HPO'},
#  {'label': ['Schizopyrenida'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_41165',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizophora'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_43738',
#   'subclasses': [obo.NCBITaxon_43741, obo.NCBITaxon_43742],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizotrypanum'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_47570',
#   'subclasses': [obo.NCBITaxon_5693],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'EFO'},
#  {'label': ['Schizosaccharomyces pombe'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4896',
#   'subclasses': [obo.NCBITaxon_284812],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['schizotypal personality disorder',
#    'schizotypal personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001087',
#   'subclasses': [],
#   'xrefs': ['DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006',
#    'DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006'],
#   'source': 'EFO'},
#  {'label': ['schizoid personality disorder', 'schizoid personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001161',
#   'subclasses': [],
#   'xrefs': ['DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000',
#    'DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizosaccharomyces pombe 972h-'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_284812',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizosaccharomyces japonicus'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4897',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizophyllum commune'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_5334',
#   'subclasses': [],
#   'xrefs': ['SNOMEDCT:243445006'],
#   'source': 'EFO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'EFO'},
#  {'label': ['hepatic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002589',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000322'],
#   'source': 'EFO'},
#  {'label': ['erythrocytic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002591',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000306'],
#   'source': 'EFO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'EFO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0005411',
#   'subclasses': [efo.EFO_0009965],
#   'xrefs': ['DOID:5418',
#    'ICD10:F25',
#    'ICD9:295.7',
#    'MONDO:0005487',
#    'MedDRA:10039621',
#    'NCIT:C94378',
#    'NCIt:C94378',
#    'SNOMEDCT:68890003'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'EFO'},
#  {'label': ['Schizoaffective disorder-bipolar type'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0009965',
#   'subclasses': [],
#   'xrefs': ['PMID:31043756',
#    'https://en.wikipedia.org/wiki/Schizoaffective_disorder'],
#   'source': 'EFO'},
#  {'label': ['schizophreniform disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001265',
#   'subclasses': [],
#   'xrefs': ['DOID:11328',
#    'ICD10CM:F20.81',
#    'ICD9:295.4',
#    'NCIT:C94376',
#    'SCTID:88975006'],
#   'source': 'EFO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'EFO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'EFO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005487',
#   'subclasses': [],
#   'xrefs': ['DOID:5418', 'EFO:0005411', 'ICD9:295.7', 'NCIT:C94378'],
#   'source': 'EFO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'EFO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'EFO'},
#  {'label': ['Schizopyrenida'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_41165',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizophora'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_43738',
#   'subclasses': [obo.NCBITaxon_43741, obo.NCBITaxon_43742],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizotrypanum'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_47570',
#   'subclasses': [obo.NCBITaxon_5693],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'MONDO'},
#  {'label': ['Schizosaccharomyces pombe'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4896',
#   'subclasses': [obo.NCBITaxon_284812],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['schizotypal personality disorder',
#    'schizotypal personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001087',
#   'subclasses': [],
#   'xrefs': ['DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006',
#    'DOID:10646',
#    'ICD9:301.22',
#    'MESH:D012569',
#    'NCIT:C92632',
#    'SCTID:31027006'],
#   'source': 'MONDO'},
#  {'label': ['schizoid personality disorder', 'schizoid personality disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001161',
#   'subclasses': [],
#   'xrefs': ['DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000',
#    'DOID:10936',
#    'ICD10CM:F60.1',
#    'ICD9:301.2',
#    'ICD9:301.20',
#    'MESH:D012557',
#    'NCIT:C92631',
#    'SCTID:52954000'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['Schizosaccharomyces pombe 972h-'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_284812',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['Schizosaccharomyces japonicus'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_4897',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['Schizophyllum commune'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_5334',
#   'subclasses': [],
#   'xrefs': ['SNOMEDCT:243445006'],
#   'source': 'MONDO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'MONDO'},
#  {'label': ['hepatic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002589',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000322'],
#   'source': 'MONDO'},
#  {'label': ['erythrocytic schizont'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0002591',
#   'subclasses': [],
#   'xrefs': ['IDOMAL:0000306'],
#   'source': 'MONDO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'MONDO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0005411',
#   'subclasses': [efo.EFO_0009965],
#   'xrefs': ['DOID:5418',
#    'ICD10:F25',
#    'ICD9:295.7',
#    'MONDO:0005487',
#    'MedDRA:10039621',
#    'NCIT:C94378',
#    'NCIt:C94378',
#    'SNOMEDCT:68890003'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'MONDO'},
#  {'label': ['Schizoaffective disorder-bipolar type'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0009965',
#   'subclasses': [],
#   'xrefs': ['PMID:31043756',
#    'https://en.wikipedia.org/wiki/Schizoaffective_disorder'],
#   'source': 'MONDO'},
#  {'label': ['schizophreniform disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001265',
#   'subclasses': [],
#   'xrefs': ['DOID:11328',
#    'ICD10CM:F20.81',
#    'ICD9:295.4',
#    'NCIT:C94376',
#    'SCTID:88975006'],
#   'source': 'MONDO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'MONDO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'MONDO'},
#  {'label': ['schizoaffective disorder'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005487',
#   'subclasses': [],
#   'xrefs': ['DOID:5418', 'EFO:0005411', 'ICD9:295.7', 'NCIT:C94378'],
#   'source': 'MONDO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'MONDO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'MONDO'},
#  {'label': ['Schizopyrenida'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_41165',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['Schizophora'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_43738',
#   'subclasses': [obo.NCBITaxon_43741, obo.NCBITaxon_43742],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['Schizotrypanum'],
#   'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_47570',
#   'subclasses': [obo.NCBITaxon_5693],
#   'xrefs': [],
#   'source': 'MONDO'}]

# %%
search_input = alt.param(
    value='',
    bind=alt.binding(
        input='search',
        placeholder="Search Term",
        name='Search ',
    )
)


fig = alt.Chart(pd.DataFrame(obo_searcher("schizophrenia"))).mark_point(size=60).encode(
    x='label:Q',
    y='Miles_per_Gallon:Q'
)

fig.add_params(
    search_input
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/altair/vegalite/v5/api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/altair/vegalite/v5/api.py:838, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     836 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     837 original_data = getattr(copy, "data", Undefined)
# --> 838 copy.data = _prepare_data(original_data, context)
#     840 if original_data is not Undefined:
#     841     context["data"] = original_data
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/altair/vegalite/v5/api.py:111, in _prepare_data(data, context)
#     109 # consolidate inline data to top-level datasets
#     110 if context is not None and data_transformers.consolidate_datasets:
# --> 111     data = _consolidate_data(data, context)
#     113 # if data is still not a recognized type, then return
#     114 if not isinstance(data, (dict, core.Data)):
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/altair/vegalite/v5/api.py:75, in _consolidate_data(data, context)
#      72         kwds = {k: v for k, v in data.items() if k != "values"}
#      74 if values is not Undefined:
# ---> 75     name = _dataset_name(values)
#      76     data = core.NamedData(name=name, **kwds)
#      77     context.setdefault("datasets", {})[name] = values
#
# File ~/.cache/pypoetry/virtualenvs/data-expressions-XOHyUNvQ-py3.10/lib/python3.10/site-packages/altair/vegalite/v5/api.py:48, in _dataset_name(values)
#      46 if values == [{}]:
#      47     return "empty"
# ---> 48 values_json = json.dumps(values, sort_keys=True)
#      49 hsh = hashlib.md5(values_json.encode()).hexdigest()
#      50 return "data-" + hsh
#
# File ~/.python/current/lib/python3.10/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~/.python/current/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File ~/.python/current/lib/python3.10/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File ~/.python/current/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type ThingClass is not JSON serializable
# alt.Chart(...)

# %%
items = obo_searcher("schizophrenia")
items
# Out:
# [{'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'HPO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'HPO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'HPO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'HPO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'HPO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'HPO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'HPO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'HPO'},
#  {'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'EFO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'EFO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'EFO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'EFO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'EFO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'EFO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'EFO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'EFO'},
#  {'label': ['Schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/HP_0100753',
#   'subclasses': [],
#   'xrefs': ['MSH:D012559',
#    'SNOMEDCT_US:191526005',
#    'SNOMEDCT_US:58214004',
#    'UMLS:C0036341'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia', 'schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005090',
#   'subclasses': [obo.MONDO_0013696,
#    efo.EFO_0004609,
#    obo.MONDO_0013696,
#    obo.MONDO_0001484,
#    obo.MONDO_0005414,
#    obo.MONDO_0008414,
#    obo.MONDO_0010897,
#    obo.MONDO_0011294,
#    obo.MONDO_0011295,
#    obo.MONDO_0011298,
#    obo.MONDO_0011307,
#    obo.MONDO_0011552,
#    obo.MONDO_0011960,
#    obo.MONDO_0012054,
#    obo.MONDO_0013498,
#    obo.MONDO_0013506,
#    obo.MONDO_0019939,
#    obo.MONDO_0033312,
#    obo.MONDO_0800358,
#    obo.MONDO_0957430],
#   'xrefs': ['DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004',
#    'DOID:5419',
#    'EFO:0000692',
#    'HP:0100753',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.80',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'ICD9:295.90',
#    'NCIT:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'Orphanet:3140',
#    'SCTID:58214004'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia, susceptibility to',
#    'schizophrenia, susceptibility to'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0100182',
#   'subclasses': [obo.MONDO_0010943,
#    obo.MONDO_0011280,
#    obo.MONDO_0011498,
#    obo.MONDO_0012879,
#    obo.MONDO_0013089,
#    obo.MONDO_0014092],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['age of onset of schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/OBA_2001011',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['obsolete_schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0000692',
#   'subclasses': [],
#   'xrefs': ['DOID:5419',
#    'ICD10:F20',
#    'ICD9:295',
#    'ICD9:295.8',
#    'ICD9:295.85',
#    'ICD9:295.9',
#    'MeSH:D012559',
#    'MedDRA:10039626',
#    'MedDRA:10039637',
#    'MedDRA:10039638',
#    'MedDRA:10039639',
#    'MedDRA:10039640',
#    'MedDRA:10052792',
#    'NCIt:C3362',
#    'NIFSTD:birnlex_2104',
#    'OMIM:181500',
#    'OMIM:600850',
#    'OMIM:603342',
#    'OMIM:604906',
#    'OMIM:608078',
#    'OMIM:613950',
#    'OMIM:614332',
#    'OMIM:615232',
#    'OMIM:617629',
#    'SNOMEDCT:58214004'],
#   'source': 'MONDO'},
#  {'label': ['treatment refractory schizophrenia'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0004609',
#   'subclasses': [],
#   'xrefs': ['MONDO:0005414'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia symptom severity measurement'],
#   'iri': 'http://www.ebi.ac.uk/efo/EFO_0007927',
#   'subclasses': [],
#   'xrefs': ['PMID:27846195'],
#   'source': 'MONDO'},
#  {'label': ['paranoid schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0001484',
#   'subclasses': [],
#   'xrefs': ['DOID:1229',
#    'ICD10CM:F20.0',
#    'ICD9:295.3',
#    'ICD9:295.30',
#    'ICD9:295.31',
#    'ICD9:295.32',
#    'MESH:D012563',
#    'NCIT:C35006',
#    'SCTID:31658008'],
#   'source': 'MONDO'},
#  {'label': ['treatment-refractory schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#   'subclasses': [],
#   'xrefs': ['EFO:0004609'],
#   'source': 'MONDO'},
#  {'label': ['obsolete schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008413',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 1'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0008414',
#   'subclasses': [],
#   'xrefs': ['DOID:0070077', 'OMIM:181510'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 3'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010897',
#   'subclasses': [],
#   'xrefs': ['DOID:0070079', 'OMIM:600511', 'UMLS:C1838069'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 4'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0010943',
#   'subclasses': [],
#   'xrefs': ['DOID:0070080', 'OMIM:600850', 'UMLS:C1833247'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 6'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011280',
#   'subclasses': [],
#   'xrefs': ['DOID:0070082', 'OMIM:603013', 'UMLS:C1864275'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 5'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011294',
#   'subclasses': [],
#   'xrefs': ['DOID:0070081', 'OMIM:603175', 'UMLS:C1864153'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 7'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011295',
#   'subclasses': [],
#   'xrefs': ['DOID:0070083', 'OMIM:603176'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 8'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011298',
#   'subclasses': [],
#   'xrefs': ['DOID:0070084', 'OMIM:603206', 'UMLS:C1864124'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 2'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011307',
#   'subclasses': [],
#   'xrefs': ['DOID:0070078', 'OMIM:603342', 'UMLS:C1864010'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 9'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070085', 'OMIM:604906', 'UMLS:C1858050'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 10'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011552',
#   'subclasses': [],
#   'xrefs': ['DOID:0070086', 'MESH:D012560', 'OMIM:605419'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 11'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0011960',
#   'subclasses': [],
#   'xrefs': ['DOID:0070087', 'OMIM:608078', 'UMLS:C1842605'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 12'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012054',
#   'subclasses': [],
#   'xrefs': ['DOID:0070088', 'OMIM:608543', 'UMLS:C1837893'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 14'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0012879',
#   'subclasses': [],
#   'xrefs': ['DOID:0070090', 'OMIM:612361', 'UMLS:C2677614'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 13'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013089',
#   'subclasses': [],
#   'xrefs': ['DOID:0070089', 'OMIM:613025', 'UMLS:C2751663'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 15'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013498',
#   'subclasses': [],
#   'xrefs': ['DOID:0070091', 'OMIM:613950', 'UMLS:C3151380'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 16'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0013506',
#   'subclasses': [],
#   'xrefs': ['DOID:0070092', 'OMIM:613959', 'UMLS:C3151408'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 18'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0014092',
#   'subclasses': [],
#   'xrefs': ['DOID:0070093', 'OMIM:615232', 'UMLS:C3808913'],
#   'source': 'MONDO'},
#  {'label': ['early-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0019939',
#   'subclasses': [],
#   'xrefs': ['GARD:19352', 'Orphanet:96369'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 19'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0033312',
#   'subclasses': [],
#   'xrefs': ['DOID:0080281', 'OMIM:617629', 'UMLS:CN404275'],
#   'source': 'MONDO'},
#  {'label': ['schizophrenia 17'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0800358',
#   'subclasses': [],
#   'xrefs': [],
#   'source': 'MONDO'},
#  {'label': ['childhood-onset schizophrenia'],
#   'iri': 'http://purl.obolibrary.org/obo/MONDO_0957430',
#   'subclasses': [],
#   'xrefs': ['Orphanet:641496'],
#   'source': 'MONDO'}]

# %%
def serialize_obo_subclass(item):
    subclasses = item['subclasses'] 
    if len(subclasses) == 0:
        return item
    else: 
        serialized = [{
            "label": subclass.label,
            "iri": subclass.iri,
            "subclasses": [x.name for x in list(subclass.subclasses())],
            "xrefs": subclass.hasDbXref,
        } for subclass in subclasses]
        return serialized

# %%
serialized_result = [serialize_obo_subclass(item) for item in items]

# %%
serialized_result[8]
# Out:
# {'label': ['treatment-refractory schizophrenia'],
#  'iri': 'http://purl.obolibrary.org/obo/MONDO_0005414',
#  'subclasses': [],
#  'xrefs': ['EFO:0004609'],
#  'source': 'HPO'}
