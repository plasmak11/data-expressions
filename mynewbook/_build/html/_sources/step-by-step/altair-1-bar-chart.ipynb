# %% [markdown]
# # Bar Chart
#
# Bar chart is the bread and butter of data visualization. You can basically meet 90% of business-relevant metrics with bar charts.

# %% [markdown]
# ## Explore the data
#
# Polars is my favorite dataframe library. There is an interesting open-source effort in biomedical space called OpenTargets.
#
# Downloaded the (tab-separated value) from OpenTargets:

# %% [markdown]
# ```{tab-set}
# :::{tab-item} Tab 1
# :sync: tab1
# Tab one
# :::
# :::{tab-item} Tab 2
# :sync: tab2
# Tab two
# :::
# ```

# %% [markdown]
# ![Alt text](iga_neph.png)

# %%
import polars as pl

df = pl.read_csv("data/EFO_0004194-known-drugs.tsv", separator="\t")
df.head(10)
# Out:
# shape: (10, 12)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬───────┬───────────┬───────────┐
# │ diseaseId  ┆ diseaseNam ┆ drugId     ┆ drugName  ┆ … ┆ name      ┆ phase ┆ status    ┆ source    │
# │ ---        ┆ e          ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---   ┆ ---       ┆ ---       │
# │ str        ┆ ---        ┆ str        ┆ str       ┆   ┆ str       ┆ i64   ┆ str       ┆ str       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════╪═══════════╪═══════════╡
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL4299 ┆ DAPAGLIFL ┆ … ┆ solute    ┆ 4     ┆ Not yet   ┆ https://c │
# │ 4          ┆ ulonephrit ┆ 10         ┆ OZIN      ┆   ┆ carrier   ┆       ┆ recruitin ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ family 5  ┆       ┆ g         ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ member 2  ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1168 ┆ RAMIPRIL  ┆ … ┆ angiotens ┆ 4     ┆ Not yet   ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆ in I conv ┆       ┆ recruitin ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ erting    ┆       ┆ g         ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ enzyme    ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1535 ┆ HYDROXYCH ┆ … ┆ toll like ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆ LOROQUINE ┆   ┆ receptor  ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ 7         ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1639 ┆ ALISKIREN ┆ … ┆ renin     ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆           ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆           ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …     ┆ …         ┆ …         │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL578  ┆ ENALAPRIL ┆ … ┆ angiotens ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆ in I conv ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ erting    ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ enzyme    ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1456 ┆ MYCOPHENO ┆ … ┆ inosine   ┆ 4     ┆ Unknown   ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆ LATE      ┆   ┆ monophosp ┆       ┆ status    ┆ linicaltr │
# │            ┆ is         ┆            ┆ MOFETIL   ┆   ┆ hate dehy ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ drogen…   ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1069 ┆ VALSARTAN ┆ … ┆ angiotens ┆ 4     ┆ Unknown   ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆           ┆   ┆ in II     ┆       ┆ status    ┆ linicaltr │
# │            ┆ is         ┆            ┆           ┆   ┆ receptor  ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆ type 1    ┆       ┆           ┆ ct2/s…    │
# │ EFO_000419 ┆ IGA glomer ┆ CHEMBL1690 ┆ HYDROXYCH ┆ … ┆ toll like ┆ 4     ┆ Completed ┆ https://c │
# │ 4          ┆ ulonephrit ┆            ┆ LOROQUINE ┆   ┆ receptor  ┆       ┆           ┆ linicaltr │
# │            ┆ is         ┆            ┆ SULFATE   ┆   ┆ 7         ┆       ┆           ┆ ials.gov/ │
# │            ┆            ┆            ┆           ┆   ┆           ┆       ┆           ┆ ct2/s…    │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴───────┴───────────┴───────────┘

# %% [markdown]
# ### Data Summary
#
# The data contains:
# - row-by-row information for disease IgA glomerulonephritis (IgA nephropathy)

# %% [markdown]
# ### `Mechanism of Action` is an interesting piece to know

# %% [markdown]
# ## Base Chart
# By unique number of drugs by `mechanismOfAction` category

# %%
import altair as alt

alt.Chart(df).mark_bar().encode(
    x="distinct(drugId):Q",
    y="mechanismOfAction:O",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Fix the x-axis title and get rid of y-axis title
#
# ```{note}
#
# Titles like "Distinct of drugID" won't get you any points for good data visualization.
#
# ```

# %%
import altair as alt

alt.Chart(df).mark_bar().encode(
    x=alt.X("distinct(drugId):Q").title("Number of Unique Drugs"), 
    y=alt.Y("mechanismOfAction:O").title(None),
)
# Out:
# alt.Chart(...)
